# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Extracting features of 2018 movies from Wikipedia

# %%
link =  "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link,header=0)[2]
df2 = pd.read_html (link, header=0)[3]
df3 = pd.read_html(link,header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 274  D E C E M B E R         25             Holmes & Watson
# 275  D E C E M B E R         25                        Vice
# 276  D E C E M B E R         25         On the Basis of Sex
# 277  D E C E M B E R         25                   Destroyer
# 278  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# ...

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = ''

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 274  D E C E M B E R         25             Holmes & Watson
# 275  D E C E M B E R         25                        Vice
# 276  D E C E M B E R         25         On the Basis of Sex
# 277  D E C E M B E R         25                   Destroyer
# 278  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# ...

# %%
data_2018 = df[['Title','Cast and crew','genres']]

# %%
data_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 274             Holmes & Watson
# 275                        Vice
# 276         On the Basis of Sex
# 277                   Destroyer
# 278  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 274  Etan Cohen (director/screenplay); Will Ferrell...
# 275  Adam McKay (director/screenplay); Christian Ba...
# 276  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_director(x):
    if " (director)" in x :
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (director)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
data_2018['director_name'] = data_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\2089203852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2018['director_name'] = data_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
data_2018['actor_1_name'] = data_2018['Cast and crew'].map(lambda x: get_actor1(x))
data_2018['actor_1_name']
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\1488963505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2018['actor_1_name'] = data_2018['Cast and crew'].map(lambda x: get_actor1(x))
# 0            Lin Shaye
# 1        Alex Pettyfer
# 2       Dominic Cooper
# 3          Bryan Brown
# 4          Liam Neeson
#             ...
# 274       Will Ferrell
# 275     Christian Bale
# 276     Felicity Jones
# 277      Nicole Kidman
# 278    Fionn Whitehead
# Name: actor_1_name, Length: 279, dtype: object

# %%
#create function remove screenplay with space
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
data_2018['Cast and crew']
# Out:
# 0      Adam Robitel (director); Leigh Whannell (scree...
# 1      Lauren Wolkstein (director); Christopher Radcl...
# 2      Simon West (director); Duncan Falconer, Warren...
# 3      Warwick Thornton (director); David Tranter, St...
# 4      Jaume Collet-Serra (director); Byron Willinger...
#                              ...
# 274    Etan Cohen (director/screenplay); Will Ferrell...
# 275    Adam McKay (director/screenplay); Christian Ba...
# 276    Mimi Leder (director); Daniel Stiepleman (scre...
# 277    Karyn Kusama (director); Phil Hay, Matt Manfre...
# 278    David Slade (director); Charlie Brooker (scree...
# Name: Cast and crew, Length: 279, dtype: object

# %%
data_2018['actor_2_name'] = data_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\3720641421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2018['actor_2_name'] = data_2018['Cast and crew'].map(lambda x: get_actor2(x))
# 0               Angus Sampson
# 1      James Freedson-Jackson
# 2              Austin Stowell
# 3                   Sam Neill
# 4                Vera Farmiga
#                 ...
# 274            John C. Reilly
# 275                 Amy Adams
# 276              Armie Hammer
# 277            Sebastian Stan
# 278              Will Poulter
# Name: actor_2_name, Length: 279, dtype: object

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
data_2018['actor_3_name'] = data_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\1795359357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2018['actor_3_name'] = data_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
data_2018 = data_2018.rename(columns={'Title':'movie_title'})

# %%
new_data18 = data_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_data18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 274          Etan Cohen     Will Ferrell          John C. Reilly
# 275          Adam McKay   Christian Bale               Amy Adams
# 276          Mimi Leder   Felicity Jones            Armie Hammer
# 277        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 278         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_data18['actor_2_name'] = new_data18['actor_2_name'].replace(np.nan, 'unknown')
new_data18['actor_3_name'] = new_data18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_data18['movie_title'] = new_data18['movie_title'].str.lower()

# %%
new_data18['comb'] = new_data18['actor_1_name'] + ' ' + new_data18['actor_2_name'] + ' '+ new_data18['actor_3_name'] + ' '+ new_data18['director_name'] +' ' + new_data18['genres']

# %%
new_data18.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill         unknown
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                          genres              movie_title  \
# 0       Horror Mystery Thriller  insidious: the last key
# 1                Thriller Drama         the strange ones
# 2               Action Thriller                 stratton
# 3  Western Crime Thriller Drama            sweet country
# 4       Action Thriller Mystery             the commuter
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# ...

# %% [markdown]
# # Fetching features of 2019 movies from Wikipedia

# %%
link ="https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2] 
df2 = pd.read_html (link,header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 241  D E C E M B E R         25  Spies in Disguise
# 242  D E C E M B E R         25       Little Women
# 243  D E C E M B E R         25               1917
# 244  D E C E M B E R         25         Just Mercy
# 245  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 241  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 242       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 243               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 244         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 245           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\2427931457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\21458062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\21458062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_16748\56863382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 241  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 242            Greta Gerwig        Saoirse Ronan           Emma Watson
# 243              Sam Mendes        George MacKay  Dean-Charles Chapman
# 244   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 245         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# ...

# %%
merge_df = new_data18._append(new_df19,ignore_index=True)
merge_df
# Out:
#               director_name       actor_1_name            actor_2_name  \
# 0              Adam Robitel          Lin Shaye           Angus Sampson
# 1          Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                Simon West     Dominic Cooper          Austin Stowell
# 3          Warwick Thornton        Bryan Brown               Sam Neill
# 4        Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                      ...                ...                     ...
# 520  Nick Bruno, Troy Quane         Will Smith             Tom Holland
# 521            Greta Gerwig      Saoirse Ronan             Emma Watson
# 522              Sam Mendes      George MacKay    Dean-Charles Chapman
# 523   Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 524         Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# ...

# %%
old_df = pd.read_csv('C:/Users/ishwa/OneDrive/Desktop/movies-recommendation/datasets/new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5496            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5497            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5498       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5499  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5500           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df._append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 6021  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 6022            Greta Gerwig      Saoirse Ronan           Emma Watson
# 6023              Sam Mendes      George MacKay  Dean-Charles Chapman
# 6024   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 6025         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    104
# actor_1_name       7
# actor_2_name      13
# actor_3_name      23
# genres             0
# movie_title       48
# comb             124
# dtype: int64

# %%
final_df = final_df.dropna(how ='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('C:/Users/ishwa/OneDrive/Desktop/movies-recommendation/datasets/final_data.csv',index=False)
